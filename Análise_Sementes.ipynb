# %% [markdown]
# <a href="https://colab.research.google.com/github/Odairjjr/Cupua-u-PCCT/blob/main/An%C3%A1lise_Sementes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
import pandas as pd
import io

# %%
#Entrada da base de dados por intermédio da seleção de um arquivo csv.
uploaded = files.upload()

table = pd.read_csv(io.BytesIO(uploaded[list(uploaded.keys())[0]]))
# Out:
#      <input type="file" id="files-b2fe0260-9d21-47a2-8959-a693efdf34dc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b2fe0260-9d21-47a2-8959-a693efdf34dc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Pesagem Sementes - Página1 (1).csv to Pesagem Sementes - Página1 (1).csv

# %%
y=table['Secas Peso']
x=table['Úmidas Peso']
z=table['Matriz']

# %%
#gráfico do peso das sementes úmidas
import matplotlib.pyplot as plt
plt.barh(z, x)
plt.xlabel('Peso',size=15)
plt.ylabel('Matrizes', size=15)
plt.title('Peso das sementes úmidas', size=20)
# Out:
# Text(0.5, 1.0, 'Peso das sementes úmidas')

# %%
#gráfico do peso das sementes secas
y=table['Secas Peso']
x=table['Matriz']
import matplotlib.pyplot as plt
plt.barh(z, y,color='y')
plt.xlabel('Peso',size=15)
plt.ylabel('Matrizes', size=15)
plt.title('Peso das sementes secas', size=20)
# Out:
# Text(0.5, 1.0, 'Peso das sementes secas')

# %%
#gráfico do peso das sementes úmidas
import matplotlib.pyplot as plt
plt.bar(z,x)
plt.xlabel('Matrizes',size=15)
plt.ylabel('Peso', size=15)
plt.title('Peso das sementes úmidas', size=20)
# Out:
# Text(0.5, 1.0, 'Peso das sementes úmidas')

# %%
#gráfico do peso das sementes secas
import matplotlib.pyplot as plt
plt.bar(z,y,color='y')
plt.xlabel('Matrizes',size=15)
plt.ylabel('Peso', size=15)
plt.title('Peso das sementes secas', size=20)
# Out:
# Text(0.5, 1.0, 'Peso das sementes secas')

# %%
#gráfico do peso das sementes secas
sns.barplot(z,y);
plt.xlabel('Matrizes',size=15);
plt.ylabel('Peso', size=15);
plt.title('Peso das sementes secas', size=20);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#gráfico do peso das sementes úmidas
sns.barplot(z,x);
plt.xlabel('Matrizes',size=15);
plt.ylabel('Peso', size=15);
plt.title('Peso das sementes úmidas', size=20);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#gráfico do peso das sementes secas
import seaborn as sns
sns.barplot(z,y);
plt.xlabel('Matrizes',size=15);
plt.ylabel('Peso', size=15);
plt.title('Peso das sementes secas', size=20);

# %%
display(table)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.FacetGrid(table,hue='Matriz',height=6).map(plt.scatter, 'Secas Peso','Úmidas Peso').add_legend()

# %%
import plotly.express as px
grafico = px.scatter_matrix(table, dimensions=['Secas Peso','Úmidas Peso'], color='Matriz')
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="d8190101-843d-461e-bcf8-228b1a396f14" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d8190101-843d-461e-bcf8-228b1a396f14")) {                    Plotly.newPlot(                        "d8190101-843d-461e-bcf8-228b1a396f14",                        [{"dimensions":[{"axis":{"matches":true},"label":"Secas Peso","values":[3,2,2,3,3,3,3,2,2,2]},{"axis":{"matches":true},"label":"\u00damidas Peso","values":[4,4,3,4,4,3,3,3,4,3]}],"hovertemplate":"Matriz=M1<br>%{xaxis.title.text}=%{x}<br>%{yaxis.title.text}=%{y}<extra></extra>","legendgroup":"M1","marker":{"color":"#636efa","symbol":"circle"},"name":"M1","showlegend":true,"type":"splom"},{"dimensions":[{"axis":{"matches":true},"label":"Secas Peso","values":[2,3,3,2,3,3,2,2,3,5]},{"axis":{"matches":true},"label":"\u00damidas Peso","values":[4,3,3,2,3,3,2,3,3,5]}],"hovertemplate":"Matriz=M2<br>%{xaxis.title.text}=%{x}<br>%{yaxis.title.text}=%{y}<extra></extra>","legendgroup":"M2","marker":{"color":"#EF553B","symbol":"circle"},"name":"M2","showlegend":true,"type":"splom"},{"dimensions":[{"axis":{"matches":true},"label":"Secas Peso","values":[3,4,4,3,3,4,4,3,4,4]},{"axis":{"matches":true},"label":"\u00damidas Peso","values":[3,5,4,4,4,5,4,4,4,4]}],"hovertemplate":"Matriz=M3<br>%{xaxis.title.text}=%{x}<br>%{yaxis.title.text}=%{y}<extra></extra>","legendgroup":"M3","marker":{"color":"#00cc96","symbol":"circle"},"name":"M3","showlegend":true,"type":"splom"},{"dimensions":[{"axis":{"matches":true},"label":"Secas Peso","values":[2,2,3,2,2,3,2,2,2,2]},{"axis":{"matches":true},"label":"\u00damidas Peso","values":[3,3,3,2,2,4,3,3,3,3]}],"hovertemplate":"Matriz=M4<br>%{xaxis.title.text}=%{x}<br>%{yaxis.title.text}=%{y}<extra></extra>","legendgroup":"M4","marker":{"color":"#ab63fa","symbol":"circle"},"name":"M4","showlegend":true,"type":"splom"},{"dimensions":[{"axis":{"matches":true},"label":"Secas Peso","values":[4,4,4,4,4,5,4,4,5,3]},{"axis":{"matches":true},"label":"\u00damidas Peso","values":[4,5,5,5,5,5,4,5,5,4]}],"hovertemplate":"Matriz=M5<br>%{xaxis.title.text}=%{x}<br>%{yaxis.title.text}=%{y}<extra></extra>","legendgroup":"M5","marker":{"color":"#FFA15A","symbol":"circle"},"name":"M5","showlegend":true,"type":"splom"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.888888888888888 ...

# %%
import matplotlib.pyplot as plt

y=[44.44,55.56]
x=['','55%']
plt.pie(y,labels=x,radius=1)
plt.title('M1 Pureza', size=15);
plt.show()

# %%
import matplotlib.pyplot as plt

y=[24.01,75.99]
x=['','75%']
plt.pie(y,labels=x,radius=1)
plt.title('M2 Pureza', size=15);
plt.show()

# %%
import matplotlib.pyplot as plt

y=[17.39,82.61]
x=['','82%']
plt.pie(y,labels=x,radius=1)
plt.title('M3 Pureza', size=15);
plt.show()

# %%
import matplotlib.pyplot as plt

y=[38.72,61.28]
x=['','61%']
plt.pie(y,labels=x,radius=1)
plt.title('M4 Pureza', size=15);
plt.show()

# %%
import matplotlib.pyplot as plt

y=[22.64,77.36]
x=['','77%']
plt.pie(y,labels=x,radius=1)
plt.title('M5 Pureza', size=15);
plt.show()

# %%
import matplotlib.pyplot as plt

y=[4,96]
x=['','96%']
plt.pie(y,labels=x,radius=1)
plt.title('Percentual de Germinação', size=15);
plt.show()

# %%
import matplotlib.pyplot as plt

y=[28.57,71.43]
x=['','71%']
plt.pie(y,labels=x,radius=1)
plt.title('M1 umidade', size=15);
plt.show()

# %%
import matplotlib.pyplot as plt

y=[13.79,86.21]
x=['','86%']
plt.pie(y,labels=x,radius=1)
plt.title('M2 umidade', size=15);
plt.show()

# %%
import matplotlib.pyplot as plt

y=[9.52,90.48]
x=['','90%']
plt.pie(y,labels=x,radius=1)
plt.title('M3 umidade', size=15);
plt.show()

# %%
import matplotlib.pyplot as plt

y=[24.14,75.86]
x=['','75%']
plt.pie(y,labels=x,radius=1)
plt.title('M4 umidade', size=15);
plt.show()

# %%
import matplotlib.pyplot as plt

y=[12.77,87.23]
x=['','87%']
plt.pie(y,labels=x,radius=1)
plt.title('M5 umidade', size=15);
plt.show()
